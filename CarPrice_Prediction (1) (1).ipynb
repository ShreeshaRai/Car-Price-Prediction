# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("car_price_dataset.csv")

# %%
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
df.shape
# Out:
# (10000, 10)

# %% [markdown]
# CLEANING PROCESS

# %%
df.isna()
# Out:
#       Brand  Model   Year  Engine_Size  Fuel_Type  Transmission  Mileage  \
# 0     False  False  False        False      False         False    False
# 1     False  False  False        False      False         False    False
# 2     False  False  False        False      False         False    False
# 3     False  False  False        False      False         False    False
# 4     False  False  False        False      False         False    False
# ...     ...    ...    ...          ...        ...           ...      ...
# 9995  False  False  False        False      False         False    False
# 9996  False  False  False        False      False         False    False
# 9997  False  False  False        False      False         False    False
# 9998  False  False  False        False      False         False    False
# 9999  False  False  False        False      False         False    False
#
#       Doors  Owner_Count  Price
# 0     False        False  False
# ...

# %%
df.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
#df.drop_duplicated()
# Out:
# 0

# %%
df.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
print(df.dtypes)
# Out:
# Brand            object
# Model            object
# Year              int64
# Engine_Size     float64
# Fuel_Type        object
# Transmission     object
# Mileage           int64
# Doors             int64
# Owner_Count       int64
# Price             int64
# dtype: object

# %%
#df['Brand_encoded'] = pd.factorize(df['Brand'])[0]  # Example for categorical column 'Brand'
#corr = df.corr()
#print(corr)

# %%
corr
# Out:
#                  Year  Engine_Size   Mileage     Doors  Owner_Count     Price
# Year         1.000000    -0.001306 -0.002476  0.014867     0.000116  0.663036
# Engine_Size -0.001306     1.000000  0.015135 -0.009844     0.007122  0.357403
# Mileage     -0.002476     0.015135  1.000000  0.007879     0.006287 -0.551227
# Doors        0.014867    -0.009844  0.007879  1.000000    -0.005431  0.000511
# Owner_Count  0.000116     0.007122  0.006287 -0.005431     1.000000  0.002656
# Price        0.663036     0.357403 -0.551227  0.000511     0.002656  1.000000

# %%
df.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %% [markdown]
# EDA

# %%
sns.scatterplot(data=df,x="Year",y="Price",hue="Brand")
plt.show()

# %%
sns.lineplot(x="Engine_Size",y="Price",data=df)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.displot(df, x="Price", bins=20, kde=False, hue="Brand", palette="viridis", aspect=1.5)
plt.title("Price Distribution by Brand")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
le = LabelEncoder()

# Encode the "Brand" column
df["Brand"] = le.fit_transform(df["Brand"])
df["Model"]=le.fit_transform(df["Model"])



categorical_col=['Brand','Model']
for col in categorical_col;
  le=LabelEncoder()
  df[col]=le.fit_transform(df[col])

# %%
#X=df.iloc[:, :9]
X = df.drop(columns=["Price", "Fuel_Type", "Transmission"])
print(X)
#X = df[['Year', 'Mileage', 'Engine Size']]
# Out:
#       Brand  Model  Year  Engine_Size  Mileage  Doors  Owner_Count
# 0         6     24  2020          4.2   289944      3            5
# 1         2     19  2012          2.0     5356      2            3
# 2         7     16  2020          4.2   231440      4            2
# 3         0     22  2023          2.0   160971      2            1
# 4         9     17  2003          2.6   286618      3            3
# ...     ...    ...   ...          ...      ...    ...          ...
# 9995      6     20  2004          3.7     5794      2            4
# 9996      2     18  2002          1.4   168000      2            1
# 9997      1      0  2010          3.0    86664      5            1
# 9998      3     13  2002          1.4   225772      4            1
# 9999      9     27  2001          2.1   157882      3            3
#
# [10000 rows x 7 columns]

# %%
y=df[["Price"]]
print(y)
# Out:
#       Price
# 0      8501
# 1     12092
# 2     11171
# 3     11780
# 4      2867
# ...     ...
# 9995   8884
# 9996   6240
# 9997   9866
# 9998   4084
# 9999   3342
#
# [10000 rows x 1 columns]

# %%
df
# Out:
#       Brand  Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         6     24  2020          4.2    Diesel          Manual   289944
# 1         2     19  2012          2.0    Hybrid       Automatic     5356
# 2         7     16  2020          4.2    Diesel       Automatic   231440
# 3         0     22  2023          2.0  Electric          Manual   160971
# 4         9     17  2003          2.6    Hybrid  Semi-Automatic   286618
# ...     ...    ...   ...          ...       ...             ...      ...
# 9995      6     20  2004          3.7    Diesel  Semi-Automatic     5794
# 9996      2     18  2002          1.4  Electric       Automatic   168000
# 9997      1      0  2010          3.0    Petrol       Automatic    86664
# 9998      3     13  2002          1.4    Hybrid       Automatic   225772
# 9999      9     27  2001          2.1    Diesel          Manual   157882
#
#       Doors  Owner_Count  Price
# 0         3            5   8501
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#df = pd.get_dummies(df, drop_first=True)

# %%
df
# Out:
#       Brand  Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         6     24  2020          4.2    Diesel          Manual   289944
# 1         2     19  2012          2.0    Hybrid       Automatic     5356
# 2         7     16  2020          4.2    Diesel       Automatic   231440
# 3         0     22  2023          2.0  Electric          Manual   160971
# 4         9     17  2003          2.6    Hybrid  Semi-Automatic   286618
# ...     ...    ...   ...          ...       ...             ...      ...
# 9995      6     20  2004          3.7    Diesel  Semi-Automatic     5794
# 9996      2     18  2002          1.4  Electric       Automatic   168000
# 9997      1      0  2010          3.0    Petrol       Automatic    86664
# 9998      3     13  2002          1.4    Hybrid       Automatic   225772
# 9999      9     27  2001          2.1    Diesel          Manual   157882
#
#       Doors  Owner_Count  Price
# 0         3            5   8501
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
print(X_train,X_test,y_train,y_test)
# Out:
#       Brand  Model  Year  Engine_Size  Mileage  Doors  Owner_Count
# 9069      6     20  2002          4.8    55077      2            2
# 2603      6     24  2020          2.2   148075      5            2
# 7738      1      0  2011          1.3   182449      2            3
# 1579      6     26  2010          1.3   195406      3            1
# 5058      9     21  2015          1.7    11098      4            2
# ...     ...    ...   ...          ...      ...    ...          ...
# 5734      1     29  2009          1.8   281531      4            1
# 5191      4      6  2015          4.5   223211      3            5
# 5390      1     29  2006          4.5    54111      5            5
# 860       8     23  2016          4.4   265121      3            4
# 7270      2     19  2021          1.7   215759      2            2
#
# [7000 rows x 7 columns]       Brand  Model  Year  Engine_Size  Mileage  Doors  Owner_Count
# 6252      1      0  2005          1.2   257760      5            5
# ...

# %%
df
# Out:
#       Brand  Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         6     24  2020          4.2    Diesel          Manual   289944
# 1         2     19  2012          2.0    Hybrid       Automatic     5356
# 2         7     16  2020          4.2    Diesel       Automatic   231440
# 3         0     22  2023          2.0  Electric          Manual   160971
# 4         9     17  2003          2.6    Hybrid  Semi-Automatic   286618
# ...     ...    ...   ...          ...       ...             ...      ...
# 9995      6     20  2004          3.7    Diesel  Semi-Automatic     5794
# 9996      2     18  2002          1.4  Electric       Automatic   168000
# 9997      1      0  2010          3.0    Petrol       Automatic    86664
# 9998      3     13  2002          1.4    Hybrid       Automatic   225772
# 9999      9     27  2001          2.1    Diesel          Manual   157882
#
#       Doors  Owner_Count  Price
# 0         3            5   8501
# ...

# %%
#model training
model=LinearRegression()
model.fit(X_train,y_train)
model
# Out:
# LinearRegression()

# %%
df
# Out:
#       Brand  Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         6     24  2020          4.2    Diesel          Manual   289944
# 1         2     19  2012          2.0    Hybrid       Automatic     5356
# 2         7     16  2020          4.2    Diesel       Automatic   231440
# 3         0     22  2023          2.0  Electric          Manual   160971
# 4         9     17  2003          2.6    Hybrid  Semi-Automatic   286618
# ...     ...    ...   ...          ...       ...             ...      ...
# 9995      6     20  2004          3.7    Diesel  Semi-Automatic     5794
# 9996      2     18  2002          1.4  Electric       Automatic   168000
# 9997      1      0  2010          3.0    Petrol       Automatic    86664
# 9998      3     13  2002          1.4    Hybrid       Automatic   225772
# 9999      9     27  2001          2.1    Diesel          Manual   157882
#
#       Doors  Owner_Count  Price
# 0         3            5   8501
# ...

# %%
#testing the model
y_predict=model.predict(X_test)
y_predict
# Out:
# array([[ 2897.78661502],
#        [ 9892.74408494],
#        [13397.64058335],
#        ...,
#        [ 8996.32530204],
#        [10876.98741219],
#        [13577.73960624]])

# %%
y_test
# Out:
#       Price
# 6252   2000
# 4684  11164
# 1731  14630
# 4742   7334
# 4521  10127
# ...     ...
# 8014   9802
# 1074   4624
# 3063   7719
# 6487  11079
# 4705  14305
#
# [3000 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix,mean_squared_error,r2_score,mean_absolute_error
mse=mean_squared_error(y_test,y_predict)#average difference b\w actua and predicted values
print(mse)
# Out:
# 1170824.4178572171

# %%
#mae--mean absolute error(average b\w absolute difference of predicted and actual data)
mae=mean_absolute_error(y_test,y_predict)
print(mae)
# Out:
# 905.9716723513208

# %%
# finding the accuracy in refression using R square
r2score=r2_score(y_test,y_predict)
print(r2score)
# Out:
# 0.8754859990868159

# %%
# Another algorithm Decisiontree regression  algo
from sklearn.tree import DecisionTreeRegressor
model2 = DecisionTreeRegressor(random_state=42)

# Train the model
model2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
#testing the model
y_predict2=model2.predict(X_test)
y_predict2
# Out:
# array([ 2316.,  9183., 11563., ...,  9212.,  9077., 14293.])

# %%
y_test
# Out:
#       Price
# 6252   2000
# 4684  11164
# 1731  14630
# 4742   7334
# 4521  10127
# ...     ...
# 8014   9802
# 1074   4624
# 3063   7719
# 6487  11079
# 4705  14305
#
# [3000 rows x 1 columns]

# %%
mse1=mean_squared_error(y_test,y_predict2)#average difference b\w actua and predicted values
print(mse1)
# Out:
# 2595155.055

# %%
#mae--mean absolute error(average b\w absolute difference of predicted and actual data)
mae1=mean_absolute_error(y_test,y_predict2)
print(mae1)
# Out:
# 1294.121

# %%
r2score2=r2_score(y_test,y_predict2)
print(r2score2)
# Out:
# 0.72401229940224

# %%
# Random Forest Regression Algorithm
from sklearn.ensemble import RandomForestRegressor

# %%
model3 = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
model3.fit(X_train, y_train)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
y_predict3=model3.predict(X_test)
y_predict3
# Out:
# array([ 3342.38,  9849.76, 13336.72, ...,  8805.94, 10061.95, 14042.23])

# %%
y_test
# Out:
#       Price
# 6252   2000
# 4684  11164
# 1731  14630
# 4742   7334
# 4521  10127
# ...     ...
# 8014   9802
# 1074   4624
# 3063   7719
# 6487  11079
# 4705  14305
#
# [3000 rows x 1 columns]

# %%
mse3=mean_squared_error(y_test,y_predict3)#average difference b\w actua and predicted values
print(mse3)
# Out:
# 1329516.8008096

# %%
#mae--mean absolute error(average b\w absolute difference of predicted and actual data)
mae3=mean_absolute_error(y_test,y_predict3)
print(mae3)
# Out:
# 945.6171999999999

# %%
r2score3=r2_score(y_test,y_predict3)
print(r2score3)
# Out:
# 0.8586094946216878

# %%
X_test
# Out:
#       Brand  Model  Year  Engine_Size  Mileage  Doors  Owner_Count
# 6252      1      0  2005          1.2   257760      5            5
# 4684      9     17  2013          2.9   111790      5            3
# 1731      8     23  2011          5.0    13473      5            4
# 4742      7     10  2007          3.8   133298      4            5
# 4521      4      8  2012          1.3    18611      3            5
# ...     ...    ...   ...          ...      ...    ...          ...
# 8014      5     28  2011          3.2   139866      5            3
# 1074      5     11  2005          1.8   263796      3            5
# 3063      9     27  2015          3.2   204013      4            5
# 6487      5     28  2016          2.4    86029      5            5
# 4705      2     18  2018          3.5    34705      3            2
#
# [3000 rows x 7 columns]

# %%
new_data=np.array([[1,0,2005,1.2,257760,5,5]])
predicted_price3=model.predict(new_data)
print(predicted_price3)
# Out:
# [[2897.78661502]]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_test
# Out:
#       Price
# 6252   2000
# 4684  11164
# 1731  14630
# 4742   7334
# 4521  10127
# ...     ...
# 8014   9802
# 1074   4624
# 3063   7719
# 6487  11079
# 4705  14305
#
# [3000 rows x 1 columns]

# %%
new_data=np.array([[1,0,2005,1.2,257760,5,5]])
predicted_price=model.predict(new_data)
print(predicted_price)
# Out:
# [[2897.78661502]]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_predict, cmap=['blue','yellow'], label="Predicted vs Actual")
plt.plot(y_test, y_test, color='red', linestyle='--', label="Ideal Fit (y=x)")  # Ideal regression line

# Labels and title
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Prices")
plt.legend()
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Create a DataFrame from confusion matrix
cm_df = pd.DataFrame(cm, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Plot heatmap
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix Heatmap")
plt.ylabel("Actual")
plt.xlabel("Predicted")
plt.show()

# %%
# Generate confusion matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

# Display it using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap='Blues')  # You can also try cmap='Greens', 'Oranges', etc.

plt.title("Confusion Matrix - Actual vs Predicted")
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you already have these arrays/lists
# y_test = [...]
# y_pred = [...]

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', label='Ideal Line (y=x)')

plt.xlabel('Actual Values (y_test)')
plt.ylabel('Predicted Values (y_pred)')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
actual = [10, 20, 30, 40, 50]
predicted = [12, 18, 33, 37, 52]

# Plot
plt.scatter(y_test, predicted, color='blue', label='Predicted vs Actual')
plt.plot([min(actual), max(actual)], [min(actual), max(actual)], color='red', linestyle='--', label='Ideal Line')

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.show()

# %%
#accuracy of each algorithms
print(f" Linear regression algorithm= {r2score}")
#print(f" Decision tree regression algorithm= {r2score2}")
#print(f" Random Forest regression algorithm= {r2score3}")
# Out:
#  Linear regression algorithm= 0.8754859990868159

# %%
# Save Model
import joblib
joblib.dump(model, "CarPrice_Prediction.pkl")
print("✅ Model trained and saved successfully!")
# Out:
# ✅ Model trained and saved successfully!

# %%
import joblib

# Load the model using joblib
model = joblib.load("CarPrice_Prediction.pkl")

# Check if the model loaded correctly
print(type(model))  # Should print the model type, e.g., <class 'sklearn.svm.SVC'>
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>

# %%
import os

file_path = "CarPrice_Prediction.pkl"
print("File exists:", os.path.exists(file_path))
# Out:
# File exists: True

# %%
import pickle

try:
    model = pickle.load(open("CarPrice_Prediction.pkl", "rb"))
    print("✅ Model loaded successfully!")
    print("Model type:", type(model))
except Exception as e:
    print(f"❌ Error loading model: {e}")
# Out:
# ✅ Model loaded successfully!
# Model type: <class 'numpy.ndarray'>

# %%
if hasattr(model, "predict"):
    print("✅ Model is ready for predictions!")
else:
    print("❌ Model does not have a predict method!")
# Out:
# ✅ Model is ready for predictions!

# %%
import pickle
from sklearn.linear_model import LinearRegression
import numpy as np

# Example dataset (Replace with real data)
#X_train = np.random.rand(100, 7)  # 100 rows, 7 features
#y_train = np.random.rand(100)  # Target values

# Train model
model = LinearRegression()
model.fit(X_train, y_train)  # Now it's trained!

# Save properly
with open("CarPrice_Prediction.pkl", "wb") as f:
    pickle.dump(model, f)

print("✅ Model trained and saved successfully!")
# Out:
# ✅ Model trained and saved successfully!

# %%
import pickle

# Load the trained model
with open("CarPrice_Prediction.pkl", "rb") as f:
    model = pickle.load(f)

print("✅ Model loaded successfully!")
print("Model type:", type(model))  # Should be <class 'sklearn.linear_model._base.LinearRegression'>
# Out:
# ✅ Model loaded successfully!
# Model type: <class 'sklearn.linear_model._base.LinearRegression'>

# %%
import numpy as np

# Example input (Replace with real values)
input_features = np.array([[2015, 2.0, 50000, 4, 2, 1, 0]])  # 7 features

# Predict
prediction = model.predict(input_features)[0]
print("Predicted Price:", prediction)
# Out:
# Predicted Price: [14341008.63859372]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

test_input = np.array([[1,0,2005,1.2,257760,5,5]])  # Example data
print(model.predict(test_input))  # Should return a numeric prediction
# Out:
# [[2897.78661502]]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pip install flask flask-mysql flask-mysqldb flask-bcrypt flask-login joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
html_code = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Enter Car Details</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <h2>Enter Car Details for Prediction</h2>
    <form action="{{ url_for('ml.predict') }}" method="post">
        <input type="number" name="brand" placeholder="Brand" required>
        <input type="number" name="model" placeholder="Model" required>
        <input type="number" name="year" placeholder="Year" required>
        <input type="number" step="0.1" name="engine_size" placeholder="Engine Size (L)" required>
        <input type="number" name="mileage" placeholder="Mileage (km or miles)" required>
        <input type="number" name="doors" placeholder="Number of Doors" required>
        <input type="number" name="owner_count" placeholder="Previous Owners" required>
        <button type="submit">Predict Price</button>
    </form>

    {% if app and 'auth' in app.blueprints and 'logout' in app.blueprints['auth'].url_map %}
        <a href="{{ url_for('auth.logout') }}">Logout</a>
    {% else %}
        <a href="{{ url_for('auth.login') }}">Login</a>
    {% endif %}
</body>
</html>


"""

with open(r"templates/input_form.html", "w") as file:
    file.write(html_code)

print("✅ input_form.html file created successfully!")
# Out:
# ✅ input_form.html file created successfully!

# %%
html_code = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Enter Car Details</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <h2>Enter Car Details for Prediction</h2>
    <form action="{{ url_for('ml.predict') }}" method="post">
        <input type="number" name="brand" placeholder="Brand" required>
        <input type="number" name="model" placeholder="Model" required>
        <input type="number" name="year" placeholder="Year" required>
        <input type="number" step="0.1" name="engine_size" placeholder="Engine Size (L)" required>
        <input type="number" name="mileage" placeholder="Mileage (km or miles)" required>
        <input type="number" name="doors" placeholder="Number of Doors" required>
        <input type="number" name="owner_count" placeholder="Previous Owners" required>
        <button type="submit">Predict Price</button>
    </form>

    {% if app and 'auth' in app.blueprints and 'logout' in app.blueprints['auth'].url_map %}
        <a href="{{ url_for('auth.logout') }}">Logout</a>
    {% else %}
        <a href="{{ url_for('auth.login') }}">Login</a>
    {% endif %}
</body>
</html>


"""

with open(r"templates/input_form.html", "w") as file:
    file.write(html_code)

print("✅ input_form.html file created successfully!")
# Out:
# ✅ input_form.html file created successfully!

# %%
code_html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Prediction Result</title>
    <link rel="stylesheet" href="{{ url_for('static', filename=' style.css') }}">
</head>
<body>
    <h2>Prediction Result</h2>
    <p>Your Model Predicted: <strong>{{ prediction }}</strong></p>
    <a href="{{ url_for('ml.input_form') }}">Try Again</a>
    <a href="{{ url_for('auth.logout') }}">Logout</a>
</body>
</html>

"""
with open(r"templates/result.html", "w", encoding="utf-8") as file:
    file.write(code_html)

print(" result.html file created successfully!")
# Out:
#  result.html file created successfully!

# %%
code_html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Reset Password</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <h2>Reset Password</h2>
    <form action="{{ url_for('auth.reset_password') }}" method="post">
        <input type="email" name="email" placeholder="Enter your email" required>
        <input type="password" name="new_password" placeholder="New Password" required>
        <button type="submit">Reset Password</button>
    </form>
    <a href="{{ url_for('auth.login') }}">Back to Login</a>
</body>
</html>

"""
with open(r"templates/reset_password.html", "w", encoding="utf-8") as file:
    file.write(code_html)

print(" reset_password.html file created successfully!")
# Out:
#  reset_password.html file created successfully!

# %%
code_html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Login</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <h2>Login</h2>
    <form action="{{ url_for('auth.login') }}" method="post">
        <input type="email" name="email" placeholder="Email" required>
        <input type="password" name="password" placeholder="Password" required>
        <button type="submit">Login</button>
    </form>
    <a href="{{ url_for('auth.reset_password') }}">Forgot Password?</a>
    <a href="{{ url_for('auth.signup') }}">New user? Signup here</a>
</body>
</html>

"""
with open(r"templates/login.html", "w", encoding="utf-8") as file:
    file.write(code_html)

print(" login.htmll file created successfully!")
# Out:
#  login.htmll file created successfully!

# %%
code_html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Signup</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <h2>Signup</h2>
    <form action="{{ url_for('auth.signup') }}" method="post">
        <input type="text" name="username" placeholder="Username" required>
        <input type="email" name="email" placeholder="Email" required>
        <input type="password" name="password" placeholder="Password" required>
        <button type="submit">Signup</button>
    </form>
    <a href="{{ url_for('auth.login') }}">Already registered? Login here</a>
</body>
</html>

"""
with open(r"templates/signup.html", "w", encoding="utf-8") as file:
    file.write(code_html)

print(" signup.html file created successfully!")
# Out:
#  signup.html file created successfully!

# %%
code_html="""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>ML App - Home</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='home.css') }}">
</head>
<body>
    <header>
        <h1>Welcome to ML App</h1>
        <nav>
            <ul>
                <li><a href="{{ url_for('home') }}">Home</a></li>
                <li><a href="{{ url_for('auth.login') }}">Login</a></li>
                <li><a href="{{ url_for('auth.signup') }}">Signup</a></li>
                <li><a href="{{ url_for('about') }}">About</a></li>
            </ul>
        </nav>
    </header>
    <main>
        <h2>Machine Learning App</h2>
        <p>Explore AI-powered solutions with secure authentication.</p>
        <a href="{{ url_for('auth.login') }}" class="btn">Get Started</a>
    </main>
</body>
</html>

"""
with open(r"templates/home.html", "w", encoding="utf-8") as file:
    file.write(code_html)

print(" home.html file created successfully!")
# Out:
#  home.html file created successfully!

# %%
html_code = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>About Car Price Prediction</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='about.css') }}>
</head>
<body>
    <div class="container">
        <h1>About Car Price Prediction</h1>
        <p>Car Price Prediction is a data-driven solution designed to estimate the resale value of cars based on various factors such as model, make, year, mileage, fuel type, and transmission. This tool helps users make informed decisions when buying or selling used cars.</p>
        
        <h2>Objective</h2>
        <p>The primary goal of this project is to provide an accurate and reliable estimation of car prices using historical data and predictive analytics.</p>
        
        <h2>Features</h2>
        <ul>
            <li>User-friendly interface for easy input of car details</li>
            <li>Machine learning-based price predictions</li>
            <li>Data-driven insights into market trends</li>
            <li>Supports multiple car attributes</li>
            <li>Fast and efficient estimation</li>
        </ul>
        
        <h2>Technology Stack</h2>
        <ul>
            <li><strong>Programming Language:</strong> Python</li>
            <li><strong>Libraries & Frameworks:</strong> Pandas, NumPy, Scikit-learn, Flask</li>
            <li><strong>Database:</strong> MySql</li>
            <li><strong>Frontend:</strong> HTML, CSS</li>
            <li><strong>Deployment:</strong> Flask </li>
            <li><a href="{{ url_for('home') }}">Home</a></li>
        </ul>
        
        <h2>How It Works</h2>
        <ol>
            <li>Users enter car details</li>
            <li>Machine learning model predicts the estimated price</li>
            <li>Results are displayed instantly</li>
        </ol>
        
        <h2>Applications</h2>
        <ul>
            <li>Car buyers can verify fair prices</li>
            <li>Sellers can set competitive pricing</li>
            <li>Dealerships can analyze market trends</li>
        </ul>
    </div>
</body>
</html>



"""

with open(r"templates/about.html", "w") as file:
    file.write(html_code)

print("✅ about.html file created successfully!")
# Out:
# ✅ about.html file created successfully!

# %%
pip install flask mysql-connector-python numpy pandas scikit-learn werkzeug
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.1 MB 1.9 MB/s eta 0:00:09
#    --- ------------------------------------ 1.6/16.1 MB 4.0 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/16.1 MB 4.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.7/16.1 MB 5.8 MB/s eta 0:00:02
#    -------------- ------------------------- 6.0/16.1 MB 5.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/16.1 MB 5.4 MB/s eta 0:00:02
#    ------------------ --------------------- 7.6/16.1 MB 5.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.9/16.1 MB 5.2 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.1 MB 5.3 MB/s eta 0:00:02
# ...

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
css_code = """
body {
    font-family: Arial, sans-serif;
    text-align: center;
    background-color: #f4f4f4;
    margin: 0;
    padding: 0;
}

h2 {
    color: #333;
}

/* Form Styling */
form {
    background: white;
    max-width: 400px;
    margin: 20px auto;
    padding: 20px;
    border-radius: 8px;
    box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
}

input {
    width: 90%;
    padding: 10px;
    margin: 10px 0;
    border: 1px solid #ccc;
    border-radius: 5px;
}

button {
    background: #007BFF;
    color: white;
    padding: 10px;
    border: none;
    border-radius: 5px;
    cursor: pointer;
    width: 100%;
}

button:hover {
    background: #0056b3;
}

/* Links */
a {
    display: block;
    margin-top: 10px;
    color: #007BFF;
    text-decoration: none;
}

a:hover {
    text-decoration: underline;
}

/* Flash Messages */
.flash {
    padding: 10px;
    color: white;
    text-align: center;
    width: 100%;
    margin-bottom: 10px;
}

.success {
    background: green;
}

.error {
    background: red;
}
"""

with open("static/style.css", "w") as file:
    file.write(css_code)

print("✅ style.css file created successfully!")
# Out:
# ✅ style.css file created successfully!

# %%
css_code = """
body {
    font-family: Arial, sans-serif;
    margin: 0;
    padding: 0;
    background-color: #f4f4f4;
    text-align: center;
}

header {
    background: #007BFF;
    padding: 15px;
    color: white;
    font-size: 22px;
}

nav ul {
    list-style-type: none;
    padding: 0;
}

nav ul li {
    display: inline;
    margin: 15px;
}

nav ul li a {
    color: white;
    text-decoration: none;
    font-weight: bold;
}

main {
    margin-top: 50px;
}

h2 {
    color: #333;
}

p {
    font-size: 18px;
    color: #666;
}

"""

with open("static/home.css", "w") as file:
    file.write(css_code)

print("✅ home.css file created successfully!")
# Out:
# ✅ home.css file created successfully!

# %%
css_code = """
body {
    font-family: Arial, sans-serif;
    margin: 0;
    padding: 20px;
    background-color: #f8f9fa;
}
.container {
    max-width: 800px;
    margin: 0 auto;
    background: #fff;
    padding: 20px;
    border-radius: 10px;
    box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
}
h1, h2 {
    color: #333;
}
p {
    line-height: 1.6;
    color: #555;
}
ul {
    padding-left: 20px;
}
"""

with open("static/about.css", "w") as file:
    file.write(css_code)

print("✅ about.css file created successfully!")
# Out:
# ✅ about.css file created successfully!

# %%
import mysql.connector

# Database Connection
db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Sudheer@123"  # Change this to your MySQL root password
)

cursor = db.cursor()

# Create Database
cursor.execute("CREATE DATABASE IF NOT EXISTS ml_app")
cursor.execute("USE ml_app")

# Create Users Table
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INT AUTO_INCREMENT PRIMARY KEY,
    username VARCHAR(100) NOT NULL,
    email VARCHAR(100) UNIQUE NOT NULL,
    password VARCHAR(255) NOT NULL
)
""")

# Create Car Predictions Table
cursor.execute("""
CREATE TABLE IF NOT EXISTS car_predictions (
    id INT AUTO_INCREMENT PRIMARY KEY,
    brand VARCHAR(100),
    model VARCHAR(100),
    year INT,
    engine_size FLOAT,
    mileage INT,
    doors INT,
    owner_count INT,
    predicted_price FLOAT
)
""")

db.commit()
cursor.close()
db.close()

print("Database and tables created successfully!")
# Out:
# Database and tables created successfully!

# %%
# !python app.py --port=5002

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
